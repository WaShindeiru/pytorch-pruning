# %%
# !git clone https://github.com/WaShindeiru/pytorch-pruning
# Out:
# Cloning into 'pytorch-pruning'...
# remote: Enumerating objects: 47, done.
# remote: Counting objects: 100% (47/47), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 47 (delta 19), reused 38 (delta 13), pack-reused 0 (from 0)
# Receiving objects: 100% (47/47), 22.35 KiB | 11.17 MiB/s, done.
# Resolving deltas: 100% (19/19), done.

# %%
# !unzip animals10.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: animals10/train/chicken/OIP-aanaGONsLe2ZBaxkP85c1gHaEp.jpeg
#   inflating: animals10/train/chicken/OIP-NNeTOAtbuufcw69JvcPXfAHaFj.jpeg
#   inflating: animals10/train/chicken/890.jpeg
#   inflating: animals10/train/chicken/OIP-lCc1GAs8GuBGrVjlK2SvCgHaE8.jpeg
#   inflating: animals10/train/chicken/OIP-WH_04s8tPCzBIdYIDq-VpAHaLE.jpeg
#   inflating: animals10/train/chicken/OIP-zsbhmzPIncn9f3aVuCedvgHaFj.jpeg
#   inflating: animals10/train/chicken/410.jpeg
#   inflating: animals10/train/chicken/OIP-weNICbJEJ3PboAF1nFwosAHaFj.jpeg
#   inflating: animals10/train/chicken/194.jpeg
#   inflating: animals10/train/chicken/OIP-DjrdnINQUfb38ceWnssIcwHaF8.jpeg
#   inflating: animals10/train/chicken/OIP--fJYm8A3jUH0kZicOFAlpAHaJn.jpeg
#   inflating: animals10/train/chicken/OIP-fbUSU3kgT_1izZenbLWcqAHaFj.jpeg
#   inflating: animals10/train/chicken/OIP-oI1N4GiL_g8fDDAuhqDRpAHaFj.jpeg
# ...

# %%
# !python ./pytorch-pruning/finetune.py --train --train_path="./animals10/train" --test_path="./animals10/test"
# Out:
# Traceback (most recent call last):
#   File "/content/./pytorch-pruning/finetune.py", line 336, in <module>
#     assert torch.cuda.is_available()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError
